# %%
from solsysgen import Sun, Planet, SolarSystem

star = Sun()
earth = Planet("Earth", mass=5.972e24, a=1.496e11)
mars = Planet("Mars", mass=6.39e23, a=2.279e11)

ss = SolarSystem(star, [earth, mars])
print(ss.summary())
# Out:
# Star: Sun (mass=1.988e+30 kg)
# - Earth: a=1.496e+11 m, T=365.26 days
# - Mars: a=2.279e+11 m, T=686.78 days

# %%
from solsysgen import Sun, Planet, SolarSystem

# Create the star (default values for Sun: mass, radius, luminosity)
star = Sun()

# Create planets with (name, mass [kg], orbital radius a [m], planet radius [m])
earth = Planet(
    name="Earth",
    mass=5.972e24,
    a=1.496e11,
    radius=6.371e6
)

mars = Planet(
    name="Mars",
    mass=6.39e23,
    a=2.279e11,
    radius=3.3895e6
)

# Create the solar system with the star and planets
ss = SolarSystem(star, [earth, mars])

# Print a summary (star properties + planet properties)
print(ss.summary())
