# %%
import solsysgen
import waterio

# %%
sun = solsysgen.Sun()
planets = solsysgen.generate_planets(sun=sun, n_planets=12)

# %%
system = solsysgen.SolarSystem(sun=sun, planets=planets)

# %%
help(system.plot)
# Out:
# Help on method plot in module solsysgen.system:
#
# plot(no_steps=100, step_size=5) method of solsysgen.system.SolarSystem instance
#     Plot the trajectory of the planets after propagating.
#
#     no_steps: number of steps.
#     step_size: time step in days.

# %%
system.plot()
